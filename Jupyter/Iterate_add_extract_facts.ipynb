# %%
import JupyterBase as MindJ
from importlib import reload
reload(MindJ)
MindJ.set_memory()
# Out:
# 2026-03-28 17:00:15,850 [INFO] mind.config.manager — Loaded config from /home/macaulish/workspace/MIND/mind.toml
# 2026-03-28 17:00:15,886 [INFO] mind.memory — Memory system initialized (pool=8, sem=6)

# %%
MindJ.test_extract_facts_from_file("messages.txt")
# Out:
# 2026-03-28 17:00:19,235 [INFO] mind.ops — 🧠 [LLM] ── aliyun | glm-4.6 | 2 msgs | ~1009 in_tok | ~40 out_tok | 1.62s ──
# 2026-03-28 17:00:19,235 [INFO] mind.ops —   ┊ prompt  → FACT_EXTRACTION_SYSTEM_PROMPT | Extract the key facts from the following conversation that should be remembered about the user.
#
# Conversation:
# 我老家河南的，不过在北京生活十多年了
#
# 2026-03-28 17:00:19,236 [INFO] mind.ops —   ┊ output  → {
#   "facts": [
#     {"text": "User's hometown is Henan", "confidence": 1.0},
#     {"text": "User has lived in Beijing for over ten years", "confidence": 1.0}
#   ]
# }
# 2026-03-28 17:00:20,491 [INFO] mind.ops — 🧠 [LLM] ── aliyun | glm-4.6 | 2 msgs | ~1007 in_tok | ~35 out_tok | 1.25s ──
# 2026-03-28 17:00:20,492 [INFO] mind.ops —   ┊ prompt  → FACT_EXTRACTION_SYSTEM_PROMPT | Extract the key facts from the following conversation that should be remembered about the user.
#
# Conversation:
# 刚领了结婚证，下个月办婚礼
#
# 2026-03-28 17:00:20,492 [INFO] mind.ops —   ┊ output  → {
#   "facts": [
#     {"text": "User is married", "confidence": 1.0},
#     {"text": "User is having a wedding next month", "confidence": 1.0}
#   ]
# }
# 2026-03-28 17:00:28,996 [INFO] mind.ops — 🧠 [LLM] ── aliyun | glm-4.6 | 2 msgs | ~1007 in_tok | ~36 out_tok | 8.50s ──
# 2026-03-28 17:00:28,998 [INFO] mind.ops —   ┊ prompt  → FACT_EXTRACTION_SYSTEM_PROMPT | Extract the key facts from the following conversation that should be remembered about the user.
#
# Conversation:
# 我近视500度，戴隐形眼镜
#
# 2026-03-28 17:00:28,999 [INFO] mind.ops —   ┊ output  → {
#   "facts": [
#     {"text": "User has 500-degree myopia", "confidence": 1.0},
#     {"text": "User wears contact lenses", "confidence": 1.0}
#   ]
# }
