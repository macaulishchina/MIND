# %%
import JupyterBase as MindJ
from importlib import reload
reload(MindJ)
MindJ.set_memory()
# Out:
# 2026-03-28 05:48:31,334 [INFO] mind.config.manager — Loaded config from /home/macaulish/workspace/MIND/mind.toml
# 2026-03-28 05:48:31,378 [INFO] mind.memory — Memory system initialized (pool=8, sem=6)

# %%
MindJ.test_extract_facts_from_file("messages.txt")
# Out:
# 2026-03-28 05:48:36,079 [INFO] mind.ops — 🧠 [LLM] ── aliyun | deepseek-v3.2 | 2 msgs | ~539 in_tok | ~44 out_tok | 2.90s ──
# 2026-03-28 05:48:36,080 [INFO] mind.ops —   ┊ prompt  → FACT_EXTRACTION_SYSTEM_PROMPT | Extract the key facts from the following conversation that should be remembered about the user.
#
# Conversation:
# 我老家河南的，不过在北京生活十多年了
#
# 2026-03-28 05:48:36,081 [INFO] mind.ops —   ┊ output  → {
#   "facts": [
#     {"text": "User's hometown is in Henan province", "confidence": 1.0},
#     {"text": "User has lived in Beijing for more than ten years", "confidence": 1.0}
#   ]
# }
# 2026-03-28 05:48:38,975 [INFO] mind.ops — 🧠 [LLM] ── aliyun | deepseek-v3.2 | 2 msgs | ~537 in_tok | ~27 out_tok | 2.89s ──
# 2026-03-28 05:48:38,977 [INFO] mind.ops —   ┊ prompt  → FACT_EXTRACTION_SYSTEM_PROMPT | Extract the key facts from the following conversation that should be remembered about the user.
#
# Conversation:
# 刚领了结婚证，下个月办婚礼
#
# 2026-03-28 05:48:38,979 [INFO] mind.ops —   ┊ output  → {
#   "facts": [
#     {"text": "用户刚刚领了结婚证", "confidence": 1.0},
#     {"text": "用户下个月要办婚礼", "confidence": 1.0}
#   ]
# }
# 2026-03-28 05:48:41,538 [INFO] mind.ops — 🧠 [LLM] ── aliyun | deepseek-v3.2 | 2 msgs | ~537 in_tok | ~36 out_tok | 2.56s ──
# 2026-03-28 05:48:41,538 [INFO] mind.ops —   ┊ prompt  → FACT_EXTRACTION_SYSTEM_PROMPT | Extract the key facts from the following conversation that should be remembered about the user.
#
# Conversation:
# 我近视500度，戴隐形眼镜
#
# 2026-03-28 05:48:41,539 [INFO] mind.ops —   ┊ output  → {
#   "facts": [
#     {
#       "text": "用户有500度的近视",
#       "confidence": 1.0
#     },
#     {
#       "text": "用户佩戴隐形眼镜",
#       "confidence": 1.0
#     }
#   ]
# }
