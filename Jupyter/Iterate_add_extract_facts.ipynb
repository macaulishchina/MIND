# %%
import JupyterBase as MindJ
from importlib import reload
reload(MindJ)
MindJ.set_memory()
# Out:
# 2026-03-30 03:39:46,835 [INFO] mind.config.manager — Loaded config from /home/macaulish/workspace/MIND/mind.toml
# 2026-03-30 03:39:46,869 [INFO] mind.llms.openai — OpenAILLM: batch mode ON — base_url=https://batch.dashscope.aliyuncs.com/compatible-mode/v1, timeout=3600s
# 2026-03-30 03:39:46,930 [INFO] mind.memory — Memory system initialized (pool=8, sem=6)

# %%
MindJ.test_extract_facts_from_file("messages.txt")
# Out:
# 2026-03-30 03:25:01,101 [INFO] mind.ops — 🧠 [LLM] ── aliyun | qwen3.5-flash | 2 msgs | ~1512 in_tok | ~40 out_tok | 3.42s ──
# 2026-03-30 03:25:01,104 [INFO] mind.ops —   ┊ prompt  → FACT_EXTRACTION_SYSTEM_PROMPT | Extract the key facts from the following conversation that should be remembered about the user.
#
# Conversation:
# 我老家河南的，不过在北京生活十多年了
#
# 2026-03-30 03:25:01,106 [INFO] mind.ops —   ┊ output  → {
#   "facts": [
#     {"text": "User's hometown is Henan", "confidence": 1.0},
#     {"text": "User has lived in Beijing for over ten years", "confidence": 1.0}
#   ]
# }
# 2026-03-30 03:25:05,112 [INFO] mind.ops — 🧠 [LLM] ── aliyun | qwen3.5-flash | 2 msgs | ~1511 in_tok | ~55 out_tok | 4.00s ──
# 2026-03-30 03:25:05,114 [INFO] mind.ops —   ┊ prompt  → FACT_EXTRACTION_SYSTEM_PROMPT | Extract the key facts from the following conversation that should be remembered about the user.
#
# Conversation:
# 刚领了结婚证，下个月办婚礼
#
# 2026-03-30 03:25:05,116 [INFO] mind.ops —   ┊ output  → {
# ...

# %%
MindJ.test_add("user","My name is John and I am 30 years old.")
# Out:
# 2026-03-30 03:39:47,935 [INFO] mind.memory — 📝 [ADD] ── START | user=test_user | 1 messages ──
# 2026-03-30 03:39:48,752 [INFO] mind.ops — 🧠 [LLM] ── aliyun | qwen3.5-flash | 2 msgs | ~1520 in_tok | ~34 out_tok | 0.82s ──
# 2026-03-30 03:39:48,753 [INFO] mind.ops —   ┊ prompt  → FACT_EXTRACTION_SYSTEM_PROMPT | Extract the key facts from the following conversation that should be remembered about the user.
#
# Conversation:
# User: My name is huyidong and I am 32 years old.
#
# 2026-03-30 03:39:48,754 [INFO] mind.ops —   ┊ output  → {
#   "facts": [
#     {"text": "User's name is huyidong", "confidence": 1.0},
#     {"text": "User is 32 years old", "confidence": 1.0}
#   ]
# }
# 2026-03-30 03:39:48,755 [INFO] mind.memory — Extracted 2 facts from conversation
# 2026-03-30 03:39:49,167 [INFO] mind.ops — [fact:2/2] 🔗 [EMB] ── openai-embedding | text-embedding-v4 | 20 chars | dim=1024 | 0.41s ──
# 2026-03-30 03:39:49,169 [INFO] mind.ops —   ┊ input   → User is 32 years old
# ...
