# %%
import JupyterBase as MindJ
from importlib import reload
reload(MindJ)
MindJ.set_memory()
# Out:
# 2026-03-28 03:32:30,185 [INFO] mind.config.manager — Loaded config from /home/macaulish/workspace/MIND/mind.toml
# 2026-03-28 03:32:30,224 [INFO] mind.memory — Memory system initialized (pool=8, sem=6)

# %%
MindJ.test_extract_facts_from_file("messages.txt")
# Out:
# 2026-03-28 03:32:36,850 [INFO] mind.ops — 🧠 [LLM] ── aliyun | deepseek-v3.2 | 2 msgs | ~402 in_tok | ~38 out_tok | 3.66s ──
# 2026-03-28 03:32:36,852 [INFO] mind.ops —   ┊ prompt  → FACT_EXTRACTION_SYSTEM_PROMPT | Extract the key facts from the following conversation that should be remembered about the user.
#
# Conversation:
# 我老家河南的，不过在北京生活十多年了
#
# 2026-03-28 03:32:36,854 [INFO] mind.ops —   ┊ output  → {
#   "facts": [
#     {
#       "text": "用户的籍贯（老家）是河南",
#       "confidence": 1.0
#     },
#     {
#       "text": "用户已在北京生活了十多年",
#       "confidence": 1.0
#     }
#   ]
# }
# 2026-03-28 03:32:39,955 [INFO] mind.ops — 🧠 [LLM] ── aliyun | deepseek-v3.2 | 2 msgs | ~401 in_tok | ~38 out_tok | 3.10s ──
# 2026-03-28 03:32:39,957 [INFO] mind.ops —   ┊ prompt  → FACT_EXTRACTION_SYSTEM_PROMPT | Extract the key facts from the following conversation that should be remembered about the user.
#
# Conversation:
# 刚领了结婚证，下个月办婚礼
#
# 2026-03-28 03:32:39,958 [INFO] mind.ops —   ┊ output  → {
#   "facts": [
#     {
#       "text": "用户最近刚领取了结婚证。",
#       "confidence": 1.0
#     },
#     {
#       "text": "用户计划在下个月举办婚礼。",
#       "confidence": 1.0
#     }
#   ]
# }
# 2026-03-28 03:32:43,302 [INFO] mind.ops — 🧠 [LLM] ── aliyun | deepseek-v3.2 | 2 msgs | ~401 in_tok | ~43 out_tok | 3.34s ──
# 2026-03-28 03:32:43,304 [INFO] mind.ops —   ┊ prompt  → FACT_EXTRACTION_SYSTEM_PROMPT | Extract the key facts from the following conversation that should be remembered about the user.
#
# Conversation:
# 我近视500度，戴隐形眼镜
#
# 2026-03-28 03:32:43,306 [INFO] mind.ops —   ┊ output  → {
#   "facts": [
#     {"text": "The user is nearsighted with 500 degrees of myopia.", "confidence": 1.0},
#     {"text": "The user wears contact lenses.", "confidence": 1.0}
#   ]
# }
